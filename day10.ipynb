# %%
left = {
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
}

# %%
right = {
    'C':['C0','C2','C3'],
    'D':['D0','D2','D3']
}

# %%
import pandas as pd
import numpy as np

# %%
left = pd.DataFrame(left, index = ['k0','k1','k2'])

# %%
right = pd.DataFrame(right, index = ['k0','k2','k3'])

# %%
left
# Out:
#      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2

# %%
right
# Out:
#      C   D
# k0  C0  D0
# k2  C2  D2
# k3  C3  D3

# %%
left.join(right, how = 'inner')
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k2  A2  B2  C2  D2

# %%
left.join
# Out:
# <bound method DataFrame.join of      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2>

# %%
df = pd.DataFrame({
    'col1':[444,555,666,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','ghi','xyz']
})

# %%
df
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['col1'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col1'].nunique()
# Out:
# 3

# %%
df['col1'].value_counts()
# Out:
# col1
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
def times2(x):
    return 2*x

# %%
df['col2'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col2, dtype: int64

# %%
df['col2'].apply(lambda x: x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col2, dtype: int64

# %%
df = pd.read_excel(r"/content/Dataset.xlsx")

# %%
df
# Out:
#        NAME            BREEDS  GENDER      AGE VACCINATED VACCINATED NAME  \
# 0       Max        Pomeranian    MALE        2        YES          Rabies
# 1     Bella               Pug  FEMALE        3        YES     Parvo (CPV)
# 2     Rocky        Rottweiler    MALE  30 DAYS         NO             NIL
# 3     Daisy          Labrador  FEMALE        4        YES          Rabies
# 4     Buddy   German Shepherd    MALE        1         NO             NIL
# 5      Luna               Pug  FEMALE        6         NO             NIL
# 6   Charlie            Beagle    MALE        3        YES          Rabies
# 7      Tara          Labrador  FEMALE        1         NO             NIL
# 8      Milo        Pomeranian    MALE        5        YES          Rabies
# 9     Rosie        Rottweiler  FEMALE        3         NO             NIL
# 10    Tommy            Beagle    MALE        2        YES          Rabies
# 11   Sweety  Golden Retriever  FEMALE  48 DAYS        YES     Parvo (CPV)
# ...

# %%
df.head(10)
# Out:
#       NAME           BREEDS  GENDER      AGE VACCINATED VACCINATED NAME  \
# 0      Max       Pomeranian    MALE        2        YES          Rabies
# 1    Bella              Pug  FEMALE        3        YES     Parvo (CPV)
# 2    Rocky       Rottweiler    MALE  30 DAYS         NO             NIL
# 3    Daisy         Labrador  FEMALE        4        YES          Rabies
# 4    Buddy  German Shepherd    MALE        1         NO             NIL
# 5     Luna              Pug  FEMALE        6         NO             NIL
# 6  Charlie           Beagle    MALE        3        YES          Rabies
# 7     Tara         Labrador  FEMALE        1         NO             NIL
# 8     Milo       Pomeranian    MALE        5        YES          Rabies
# 9    Rosie       Rottweiler  FEMALE        3         NO             NIL
#
#    VOMITING FAINTED TICKS APPIETITE DOG EATEN STRANGE THINGS DIARRHEA  \
# 0       YES     YES   YES        NO              YES,Plastic      YES
# ...

# %%
df.tail()
# Out:
#        NAME           BREEDS  GENDER AGE VACCINATED VACCINATED NAME  VOMITING  \
# 14     Orea         Labrador    MALE   4         NO             NIL  SOMETMES
# 15    Radha           Beagle  FEMALE   5        YES     Parvo (CPV)       YES
# 16  charlie       Rottweiler    MALE   2         NO             NaN        NO
# 17     Lily              Pug  FEMALE   3        YES     Parvo (CPV)       YES
# 18   Bubblo  German Shepherd    MALE   6        YES          Rabies       YES
#
#    FAINTED TICKS APPIETITE DOG EATEN STRANGE THINGS DIARRHEA    BEHAVIOR  \
# 14      NO   YES        NO                       No      YES  Aggressive
# 15     YES   YES       YES                       No       NO     Anxious
# 16      NO   YES        NO                 YES,Toys      YES      Scared
# 17     YES   YES       YES              YES,Garbage       NO     Anxious
# 18     YES    NO        NO                       NO      YES      Scared
#
#       HEALTH PROBLEM HAIR LOSS TARGET
# ...

# %%
df.columns
# Out:
# Index(['NAME', 'BREEDS', 'GENDER', 'AGE', 'VACCINATED', 'VACCINATED NAME',
#        'VOMITING', 'FAINTED', 'TICKS', 'APPIETITE', 'DOG EATEN STRANGE THINGS',
#        'DIARRHEA', 'BEHAVIOR', 'HEALTH PROBLEM', 'HAIR LOSS', 'TARGET'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['NAME',
#  'BREEDS',
#  'GENDER',
#  'AGE',
#  'VACCINATED',
#  'VACCINATED NAME',
#  'VOMITING',
#  'FAINTED',
#  'TICKS',
#  'APPIETITE',
#  'DOG EATEN STRANGE THINGS',
#  'DIARRHEA',
#  'BEHAVIOR',
#  'HEALTH PROBLEM',
#  'HAIR LOSS',
#  'TARGET']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   NAME                      19 non-null     object
#  1   BREEDS                    19 non-null     object
#  2   GENDER                    19 non-null     object
#  3   AGE                       19 non-null     object
#  4   VACCINATED                19 non-null     object
#  5   VACCINATED NAME           18 non-null     object
#  6   VOMITING                  19 non-null     object
#  7   FAINTED                   19 non-null     object
#  8   TICKS                     19 non-null     object
#  9   APPIETITE                 19 non-null     object
#  10  DOG EATEN STRANGE THINGS  19 non-null     object
#  11  DIARRHEA                  19 non-null     object
#  12  BEHAVIOR                  19 non-null     object
# ...

# %%
df.nunique()
# Out:
# NAME                        19
# BREEDS                       7
# GENDER                       2
# AGE                          9
# VACCINATED                   2
# VACCINATED NAME              4
# VOMITING                     3
# FAINTED                      2
# TICKS                        2
# APPIETITE                    2
# DOG EATEN STRANGE THINGS     5
# DIARRHEA                     2
# BEHAVIOR                     3
# HEALTH PROBLEM               3
# HAIR LOSS                    2
# TARGET                       2
# dtype: int64

# %%
df.head(20)
# Out:
#        NAME            BREEDS  GENDER      AGE VACCINATED VACCINATED NAME  \
# 0       Max        Pomeranian    MALE        2        YES          Rabies
# 1     Bella               Pug  FEMALE        3        YES     Parvo (CPV)
# 2     Rocky        Rottweiler    MALE  30 DAYS         NO             NIL
# 3     Daisy          Labrador  FEMALE        4        YES          Rabies
# 4     Buddy   German Shepherd    MALE        1         NO             NIL
# 5      Luna               Pug  FEMALE        6         NO             NIL
# 6   Charlie            Beagle    MALE        3        YES          Rabies
# 7      Tara          Labrador  FEMALE        1         NO             NIL
# 8      Milo        Pomeranian    MALE        5        YES          Rabies
# 9     Rosie        Rottweiler  FEMALE        3         NO             NIL
# 10    Tommy            Beagle    MALE        2        YES          Rabies
# 11   Sweety  Golden Retriever  FEMALE  48 DAYS        YES     Parvo (CPV)
# ...

# %%
df.head()
# Out:
#     NAME           BREEDS  GENDER      AGE VACCINATED VACCINATED NAME  \
# 0    Max       Pomeranian    MALE        2        YES          Rabies
# 1  Bella              Pug  FEMALE        3        YES     Parvo (CPV)
# 2  Rocky       Rottweiler    MALE  30 DAYS         NO             NIL
# 3  Daisy         Labrador  FEMALE        4        YES          Rabies
# 4  Buddy  German Shepherd    MALE        1         NO             NIL
#
#    VOMITING FAINTED TICKS APPIETITE DOG EATEN STRANGE THINGS DIARRHEA  \
# 0       YES     YES   YES        NO              YES,Plastic      YES
# 1  SOMETMES     YES   YES        NO                       No       NO
# 2        NO      NO   YES        NO                       No       NO
# 3       YES     YES   YES        NO              YES,Garbage       NO
# 4        NO      NO   YES       YES                 YES,Toys      YES
#
#      BEHAVIOR    HEALTH PROBLEM HAIR LOSS TARGET
# 0  Aggressive         YES,WORMS       YES    YES
# ...

# %%
df = pd.read_excel(r"/content/college_student_placement_dataset.xlsx")

# %%
df
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0       CLG0030  107             6.61  6.28                     8
# 1       CLG0061   97             5.52  5.37                     8
# 2       CLG0036  109             5.36  5.83                     9
# 3       CLG0055  122             5.47  5.75                     6
# 4       CLG0004   96             7.91  7.69                     7
# ...         ...  ...              ...   ...                   ...
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                       No                       8                     8
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (9,6))
plt.plot(df['CGPA'], df['Projects_Completed'])
plt.show()

# %%
data={
    'names':['rani','raja','max','dola'],
    'student_id':[101,102,103,104],
    'subjects':['tamil','english','maths','social'],
    'rank':[2,3,1,5]

}

# %%
df
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0       CLG0030  107             6.61  6.28                     8
# 1       CLG0061   97             5.52  5.37                     8
# 2       CLG0036  109             5.36  5.83                     9
# 3       CLG0055  122             5.47  5.75                     6
# 4       CLG0004   96             7.91  7.69                     7
# ...         ...  ...              ...   ...                   ...
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                       No                       8                     8
# ...
