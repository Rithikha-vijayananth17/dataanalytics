# %%
import pandas as pd

# %%
df=pd.read_csv("/content/dataset.csv")

# %%
df
# Out:
#       Name             Breed  Age  Gender  Weight (kg) Vaccinated Dewormed  \
# 0    Dog_1       Rajapalayam    1  Female         28.0         No       No
# 1    Dog_2               Pug    7    Male         14.1         No       No
# 2    Dog_3  Golden Retriever    4    Male          6.1         No      Yes
# 3    Dog_4   German Shepherd    4    Male         13.9        Yes      Yes
# 4    Dog_5        Pomeranian    3  Female         11.8         No       No
# 5    Dog_6            Beagle    8  Female         19.6         No      Yes
# 6    Dog_7            Beagle    5  Female         21.6         No      Yes
# 7    Dog_8           Bulldog    2    Male         24.7         No       No
# 8    Dog_9        Pomeranian    1    Male         20.6         No       No
# 9   Dog_10               Pug    9  Female         19.8        Yes       No
# 10  Dog_11            Beagle    7    Male         12.6        Yes      Yes
# ...

# %%
df.dropna()
# Out:
#       Name             Breed  Age  Gender  Weight (kg) Vaccinated Dewormed  \
# 0    Dog_1       Rajapalayam    1  Female         28.0         No       No
# 1    Dog_2               Pug    7    Male         14.1         No       No
# 2    Dog_3  Golden Retriever    4    Male          6.1         No      Yes
# 3    Dog_4   German Shepherd    4    Male         13.9        Yes      Yes
# 4    Dog_5        Pomeranian    3  Female         11.8         No       No
# 5    Dog_6            Beagle    8  Female         19.6         No      Yes
# 6    Dog_7            Beagle    5  Female         21.6         No      Yes
# 7    Dog_8           Bulldog    2    Male         24.7         No       No
# 8    Dog_9        Pomeranian    1    Male         20.6         No       No
# 9   Dog_10               Pug    9  Female         19.8        Yes       No
# 10  Dog_11            Beagle    7    Male         12.6        Yes      Yes
# ...

# %%
d={
    'A':['A',56,'APPLE','TVM'],
    'B':['B',45,'BANANA','GOA'],
    'C':['C',28,'ORANGE','VPM'],
    'D':['D',89,'GUAVA','CHENNAI']

}

# %%
df=pd.DataFrame(d)
df
# Out:
#        A       B       C        D
# 0      A       B       C        D
# 1     56      45      28       89
# 2  APPLE  BANANA  ORANGE    GUAVA
# 3    TVM     GOA     VPM  CHENNAI

# %%
# Out:
#       Name             Breed  Age  Gender  Weight (kg) Vaccinated Dewormed  \
# 0    Dog_1       Rajapalayam    1  Female         28.0         No       No
# 1    Dog_2               Pug    7    Male         14.1         No       No
# 2    Dog_3  Golden Retriever    4    Male          6.1         No      Yes
# 3    Dog_4   German Shepherd    4    Male         13.9        Yes      Yes
# 4    Dog_5        Pomeranian    3  Female         11.8         No       No
# 5    Dog_6            Beagle    8  Female         19.6         No      Yes
# 6    Dog_7            Beagle    5  Female         21.6         No      Yes
# 7    Dog_8           Bulldog    2    Male         24.7         No       No
# 8    Dog_9        Pomeranian    1    Male         20.6         No       No
# 9   Dog_10               Pug    9  Female         19.8        Yes       No
# 10  Dog_11            Beagle    7    Male         12.6        Yes      Yes
# ...
