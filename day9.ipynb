# %%
import numpy as np
import pandas as pd
d={
    'A':[56,'APPLE','TVM'],
    'B':['B',45,'GOA'],
    'C':['C',28,np.nan],
    'D':['D','GUAVA','CHENNAI']

}

# %%
df=pd.DataFrame(d)
df
# Out:
#        A    B    C        D
# 0     56    B    C        D
# 1  APPLE   45   28    GUAVA
# 2    TVM  GOA  NaN  CHENNAI

# %%
df.dropna()
# Out:
#        A   B   C      D
# 0     56   B   C      D
# 1  APPLE  45  28  GUAVA

# %%
df.dropna(axis=1)
# Out:
#        A    B        D
# 0     56    B        D
# 1  APPLE   45    GUAVA
# 2    TVM  GOA  CHENNAI

# %%
df.dropna()
# Out:
#        A   B   C      D
# 0     56   B   C      D
# 1  APPLE  45  28  GUAVA

# %%
df.dropna(axis=1)
# Out:
#        A    B        D
# 0     56    B        D
# 1  APPLE   45    GUAVA
# 2    TVM  GOA  CHENNAI

# %%
df
# Out:
#        A    B    C        D
# 0     56    B    C        D
# 1  APPLE   45   28    GUAVA
# 2    TVM  GOA  NaN  CHENNAI

# %%
df.fillna(value = 'Filling Value')
# Out:
#        A    B              C        D
# 0     56    B              C        D
# 1  APPLE   45             28    GUAVA
# 2    TVM  GOA  Filling Value  CHENNAI

# %%
df=pd.DataFrame(d)

# %%
df['C_numeric'] = pd.to_numeric(df['C'], errors='coerce')
df['C_filled'] = df['C_numeric'].fillna(df['C_numeric'].mean())
df
# Out:
#        A    B    C        D  C_numeric  C_filled
# 0     56    B    C        D        NaN      28.0
# 1  APPLE   45   28    GUAVA       28.0      28.0
# 2    TVM  GOA  NaN  CHENNAI        NaN      28.0

# %%
# Out:
# 0      C
# 1     28
# 2    NaN
# Name: C, dtype: object

# %%
df
# Out:
#        A    B    C        D
# 0     56    B    C        D
# 1  APPLE   45   28    GUAVA
# 2    TVM  GOA  NaN  CHENNAI

# %%
data = {
    'Company':['Google', 'Google', 'MSFT', 'FB','FB','IBM'],
    'Person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales': [200, 120, 340, 124, 243, 350]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
m = df.groupby('Company')

# %%
df.mean(numeric_only=True)
# Out:
# Sales    229.5
# dtype: float64

# %%
m.sum()
# Out:
#            Person  Sales
# Company
# FB       VanRakib    367
# Google   SamNihad    320
# IBM           Ovi    350
# MSFT          Any    340

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df['Sales'].std()
# Out:
# 100.89945490437498

# %%
df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# Google        2      2
# IBM           1      1
# MSFT          1      1

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Google    2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IBM       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
df1 = pd.DataFrame(np.random.randint(1, 20, size = (4, 3)), [1,2,3,4], ['W', 'X', 'Y'])

# %%
df2 = pd.DataFrame(np.random.randint(20,40, size = (4, 3)), [5,6,7,8], ['W', 'X', 'Y'])

# %%
df3 = pd.DataFrame(np.random.randint(40,60, size = (4, 3)), [9,10,11,12], ['W', 'X', 'Y'])

# %%
df1
# Out:
#     W   X   Y
# 1  14   2  19
# 2  15  15   1
# 3  19   3   7
# 4   7  18   5

# %%
df2
# Out:
#     W   X   Y
# 5  38  33  24
# 6  33  32  26
# 7  37  31  21
# 8  20  20  27

# %%
df3
# Out:
#      W   X   Y
# 9   54  56  51
# 10  50  51  56
# 11  57  44  47
# 12  41  44  51

# %%
farme = [df1, df2, df3]

# %%
pd.concat(farme)
# Out:
#      W   X   Y
# 1   14   2  19
# 2   15  15   1
# 3   19   3   7
# 4    7  18   5
# 5   38  33  24
# 6   33  32  26
# 7   37  31  21
# 8   20  20  27
# 9   54  56  51
# 10  50  51  56
# 11  57  44  47
# 12  41  44  51

# %%
pd.concat(farme, axis = 1)
# Out:
#        W     X     Y     W     X     Y     W     X     Y
# 1   14.0   2.0  19.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   15.0  15.0   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   19.0   3.0   7.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4    7.0  18.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  38.0  33.0  24.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  33.0  32.0  26.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  37.0  31.0  21.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  20.0  20.0  27.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  54.0  56.0  51.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  50.0  51.0  56.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  57.0  44.0  47.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  41.0  44.0  51.0

# %%
left = {
    'key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}

# %%
right = {
    'key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[11,12,13,14]
}

# %%
left = pd.DataFrame(left)

# %%
right = pd.DataFrame(right)

# %%
left
# Out:
#   key   A  B
# 0  k0  10  1
# 1  k1  20  2
# 2  k2  30  3
# 3  k3  40  4

# %%
right
# Out:
#   key    C   D
# 0  k0  100  11
# 1  k1  200  12
# 2  k2  300  13
# 3  k3  400  14

# %%
pd.merge(left, right, on='key')
# Out:
#   key   A  B    C   D
# 0  k0  10  1  100  11
# 1  k1  20  2  200  12
# 2  k2  30  3  300  13
# 3  k3  40  4  400  14
