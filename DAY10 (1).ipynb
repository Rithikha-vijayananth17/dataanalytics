# %%
data={
    'names':['rani','raja','max','dola'],
    'student_id':[101,102,103,104],
    'subjects':['tamil','english','maths','social'],
    'rank':[2,3,1,5]

}

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(data)
df
# Out:
#   names  student_id subjects  rank
# 0  rani         101    tamil     2
# 1  raja         102  english     3
# 2   max         103    maths     1
# 3  dola         104   social     5

# %%
df.head()
# Out:
#   names  student_id subjects  rank
# 0  rani         101    tamil     2
# 1  raja         102  english     3
# 2   max         103    maths     1
# 3  dola         104   social     5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   names       4 non-null      object
#  1   student_id  4 non-null      int64
#  2   subjects    4 non-null      object
#  3   rank        4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes

# %%
df.tail()
# Out:
#   names  student_id subjects  rank
# 0  rani         101    tamil     2
# 1  raja         102  english     3
# 2   max         103    maths     1
# 3  dola         104   social     5

# %%
df.columns
# Out:
# Index(['names', 'student_id', 'subjects', 'rank'], dtype='object')

# %%
import pandas as pd

# %%
data = {
    'Math': [80, 90, 70, 65, 85],
    'Science': [75, 88, 92, 60, 77],
    'English': [78, 85, 83, 70, 90]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    Math  Science  English
# 0    80       75       78
# 1    90       88       85
# 2    70       92       83
# 3    65       60       70
# 4    85       77       90

# %%
df.mean()
# Out:
# Math       78.0
# Science    78.4
# English    81.2
# dtype: float64

# %%
df.median()
# Out:
# Math       80.0
# Science    77.0
# English    83.0
# dtype: float64

# %%
df.std()
# Out:
# Math       10.368221
# Science    12.541930
# English     7.596052
# dtype: float64
